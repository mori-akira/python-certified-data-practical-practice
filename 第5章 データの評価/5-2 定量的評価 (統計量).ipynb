# %%
import pandas as pd

df = pd.read_parquet("../result/penguins.parquet")
df.describe()
# Out:
#                             Date_Egg  Culmen_Length  Culmen_Depth  \
# count                            344     342.000000    342.000000
# mean   2008-11-27 03:46:02.790697728      43.921930     17.151170
# min              2007-11-09 00:00:00      32.100000     13.100000
# 25%              2007-11-28 00:00:00      39.225000     15.600000
# 50%              2008-11-09 00:00:00      44.450000     17.300000
# 75%              2009-11-16 00:00:00      48.500000     18.700000
# max              2009-12-01 00:00:00      59.600000     21.500000
# std                              NaN       5.459584      1.974793
#
#        Flipper_Length    Body_Mass
# count      342.000000   342.000000
# mean       200.915205  4201.754386
# min        172.000000  2700.000000
# 25%        190.000000  3550.000000
# 50%        197.000000  4050.000000
# 75%        213.000000  4750.000000
# max        231.000000  6300.000000
# std         14.061714   801.954536

# %%
df.describe(include="all")
# Out:
#                                     Species  Island Individual_ID  \
# count                                   344     344           344
# unique                                    3       3           190
# top     Adelie Penguin (Pygoscelis adeliae)  Biscoe          N6A1
# freq                                    152     168             3
# mean                                    NaN     NaN           NaN
# min                                     NaN     NaN           NaN
# 25%                                     NaN     NaN           NaN
# 50%                                     NaN     NaN           NaN
# 75%                                     NaN     NaN           NaN
# max                                     NaN     NaN           NaN
# std                                     NaN     NaN           NaN
#
#                              Date_Egg  Culmen_Length  Culmen_Depth  \
# count                             344     342.000000    342.000000
# ...

# %%
df.loc[:, "Body_Mass"].describe()
# Out:
# count     342.000000
# mean     4201.754386
# std       801.954536
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4750.000000
# max      6300.000000
# Name: Body_Mass, dtype: float64

# %%
df.loc[0, :].describe()
# Out:
# count                                      11
# unique                                     11
# top       Adelie Penguin (Pygoscelis adeliae)
# freq                                        1
# Name: 0, dtype: object

# %%
# 任意の分位点の値を計算
df.loc[:, "Body_Mass"].quantile([0.1, 0.2, 0.75, 0.8, 0.9, 0.95, 0.99, 1])
# Out:
# 0.10    3300.0
# 0.20    3475.0
# 0.75    4750.0
# 0.80    4950.0
# 0.90    5400.0
# 0.95    5650.0
# 0.99    5979.5
# 1.00    6300.0
# Name: Body_Mass, dtype: float64

# %%
# 出現頻度
df.loc[:, "Species_Short"].value_counts()
# Out:
# Species_Short
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64
