# %%
from PIL import Image

# Pillowで画像読み込み
im = Image.open("../data/sample.png")
print(im.format)
print(im.size)
print(im.mode)
# Out:
# PNG
# (864, 409)
# RGBA

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=864x409>

# %%
im.close()

print(im.format)
print(im.size)
print(im.mode)
# Out:
# PNG
# (864, 409)
# RGBA
