# %%
import pandas as pd

pd.read_json("../data/給与データ.json")
# Out:
#                                                  FY21  \
# 1   {'detail': [{'data': [{'data': 191.5, 'key': '...
# 2   {'detail': [{'data': [{'data': 204, 'key': '勤務...
# 3   {'detail': [{'data': [{'data': 154.5, 'key': '...
# 4   {'detail': [{'data': [{'data': 170, 'key': '勤務...
# 5   {'detail': [{'data': [{'data': 143.5, 'key': '...
# 6   {'detail': [{'data': [{'data': 176, 'key': '勤務...
# 7   {'detail': [{'data': [{'data': 207.5, 'key': '...
# 8   {'detail': [{'data': [{'data': 227.75, 'key': ...
# 9   {'detail': [{'data': [{'data': 196.25, 'key': ...
# 10  {'detail': [{'data': [{'data': 269.5, 'key': '...
# 11  {'detail': [{'data': [{'data': 183, 'key': '勤務...
# 12  {'detail': [{'data': [{'data': 235.25, 'key': ...
#
#                                                  FY22  \
# 1   {'detail': [{'data': [{'data': 7, 'key': '出勤'}...
# 2   {'detail': [{'data': [{'data': 21, 'key': '出勤'...
# 3   {'detail': [{'data': [{'data': 18, 'key': '出勤'...
# ...

# %%
import json

with open("../data/給与データ.json", "r", encoding="utf-8") as f:
    data = json.load(f)

pd.json_normalize(data)
# Out:
#                                        FY21.1.detail  FY21.1.overview.bonus  \
# 0  [{'data': [{'data': 191.5, 'key': '勤務時間'}, {'d...                      0
#
#    FY21.1.overview.bonusTakeHome  FY21.1.overview.grossIncome  \
# 0                              0                       251964
#
#    FY21.1.overview.netIncome  FY21.1.overview.operatingTime  \
# 0                     209538                          193.5
#
#    FY21.1.overview.overtime  FY21.1.overview.payslipId  FY21.1.payslipId  \
# 0                        35                         36                36
#
#    FY21.1.salaryStructure.basicSalary  ...  FY25.12.payslipId  \
# 0                              220000  ...                 55
#
#    FY25.12.salaryStructure.basicSalary  FY25.12.salaryStructure.bonus  \
# 0                               299500                        1022000
#
#    FY25.12.salaryStructure.housingAllowance  FY25.12.salaryStructure.other  \
# ...
