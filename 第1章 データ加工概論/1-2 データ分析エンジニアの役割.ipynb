# %% [markdown]
# ## データ分析エンジニアに必要な最低限の技術
# - <m-b>データの入手、加工</m-b>
# - <m-b>データの可視化</m-b>
# - <m-b>データ特性の把握</m-b>
# - <m-b>プログラミング</m-b>
# - <m-b>インフラ知識</m-b>
#
# ### 付加的に持つべき知識
# - <m-b>機械学習</m-b>
# - <m-b>数学</m-b>
# - <m-b>ドメイン知識</m-b>
#
# ## データサイエンティストの役割
# - <m-b>機械学習</m-b>、<m-b>統計モデル</m-b>、<m-b>アルゴリズム</m-b>の構築
# - 新たな解法や新技術への取り組み
# - さまざまな<m-b>課題</m-b>に向き合う実務
# - <m-b>データ</m-b>との向き合い方の提示
# - 分析結果の<m-b>評価</m-b>、<m-b>説明</m-b>
